# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
df.shape
# Out:
# (100000, 28)

# %%
df.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
df1 = df.copy()

# %%
# unique features are converted to string dtype to avoid in stats caluculation
df1['ID'] = df1['ID'].astype(str)
df1['Customer_ID'] = df1['Customer_ID'].astype(str)
df1['Age'] = df1['Age'].astype(str)
df1['SSN'] = df1['SSN'].astype(str)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df2 = df1.drop(['SSN','Month'],axis=1) # drop this unique features we need note have it in our dataset to train our model
df2
# Out:
#            ID Customer_ID           Name   Age Occupation  Annual_Income  \
# 0        5634        3392  Aaron Maashoh  23.0  Scientist       19114.12
# 1        5635        3392  Aaron Maashoh  23.0  Scientist       19114.12
# 2        5636        3392  Aaron Maashoh  23.0  Scientist       19114.12
# 3        5637        3392  Aaron Maashoh  23.0  Scientist       19114.12
# 4        5638        3392  Aaron Maashoh  23.0  Scientist       19114.12
# ...       ...         ...            ...   ...        ...            ...
# 99995  155625       37932          Nicks  25.0   Mechanic       39628.99
# 99996  155626       37932          Nicks  25.0   Mechanic       39628.99
# 99997  155627       37932          Nicks  25.0   Mechanic       39628.99
# 99998  155628       37932          Nicks  25.0   Mechanic       39628.99
# 99999  155629       37932          Nicks  25.0   Mechanic       39628.99
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
# our dataset contains the details in month wise for the same person(the banking details duplicated), we will make it summarized based on the name.

def name_df(df, name):    
    df_name = df[df['Name'] == name]
    
    df_name1 = df_name.select_dtypes(include=[np.number]).agg('mean').to_frame(name='MeanValue').reset_index().T
    df_name1.columns = df_name1.iloc[0]
    df_name3 = df_name1.drop('index').reset_index(drop=True)
    
    df_name2 = df_name.select_dtypes(include='object').mode().iloc[0].reset_index().T
    df_name2.columns = df_name2.iloc[0]
    df_name4 = df_name2.drop('index').reset_index(drop=True)
    
    df_name5 = pd.concat([df_name3,df_name4],axis=1)
    return df_name5

# %%
unique_names = df2['Name'].unique()
df_name_summary = pd.concat([name_df(df2,name) for name in unique_names], ignore_index=True)
df_name_summary # summarized dataset
# Out:
# index Annual_Income Monthly_Inhand_Salary Num_Bank_Accounts Num_Credit_Card  \
# 0          19114.12           1824.843333               3.0             4.0
# 1          34847.84           3037.986667               2.0             4.0
# 2      55819.329167           4721.277431          7.333333             6.5
# 3      33800.716667           2736.393056               4.0        4.333333
# 4      45654.456667           3866.871389          7.333333             6.0
# ...             ...                   ...               ...             ...
# 10123      15319.65             1460.6375               6.0             7.0
# 10124      22620.79           1722.065833              6.75            2.75
# 10125       37188.1           3097.008333               1.0             4.0
# 10126      20002.88           1929.906667              10.0             8.0
# 10127      39628.99           3359.415833               4.0             6.0
#
# ...

# %%
df_name_summary.to_csv("df_name_summary.csv",index=False)
